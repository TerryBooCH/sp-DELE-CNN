# %% [markdown]
# <h1><Center>Convolutional Neural Network</Center></h1>

# %% [markdown]
# # **Imports**

# %% [markdown]
# ## Libraries
# - Import all neccessary libraries needed for the code to work.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Conv2D, Dropout, Flatten, MaxPooling2D, LeakyReLU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing import image
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV

import os
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from collections import Counter


# ignore warnings
import pickle
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import the images using PIL import Image
# - PIL allows easy loading of images.
# - provides a wide range of functions for manipulating images, such as cropping, rotating, resizing, etc.
# - Can be used to do basic analysis on images such as image properties and converting to grayscale.

# %%
def get_images(base_folder):
    images = [] 
    labels = []
    for folder_name in os.listdir(base_folder):
        label = folder_name
        folder_path = os.path.join(base_folder, folder_name)
        for file_name in os.listdir(folder_path):

            # Get path
            img_path = os.path.join(folder_path, file_name)
            
            # Open the image
            img = Image.open(img_path)

            # Convert RGB images to grayscale
            img = img.convert('L')
            
            # Resize to 131x131
            img = img.resize((131, 131))
            img_array = np.array(img)

            # Check if the images are not empty
            if img_array.size > 0:  
                images.append(img_array) 
                labels.append(label)
    
    return images, labels

# training images and labels
X_train, y_train_labels = get_images('Dataset for CA1 part A - AY2425S1/train')

# test images and labels
X_test, y_test_labels = get_images('Dataset for CA1 part A - AY2425S1/test')

# validation images and labels
X_validation, y_validation_labels = get_images('Dataset for CA1 part A - AY2425S1/validation')

# %% [markdown]
# ## Visualising some of the images
# - After grayscale and resizing

# %%
def show_one_image_per_label(images, labels):
    unique_labels = np.unique(labels)
    num_labels = len(unique_labels)
    num_cols = 4
    num_rows = num_labels // num_cols + (1 if num_labels % num_cols != 0 else 0)
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 15))

    for i, label in enumerate(unique_labels):
        img_index = labels.index(label)
        img = images[img_index]
        row = i // num_cols
        col = i % num_cols
        if num_rows > 1:
            axes[row, col].imshow(img, cmap='gray')
            axes[row, col].set_title(label)
            axes[row, col].axis('off')
        else:
            axes[col].imshow(img, cmap='gray')
            axes[col].set_title(label)
            axes[col].axis('off')

    # Remove the last empty subplot if necessary
    if num_labels % num_cols != 0:
        empty_row = num_labels // num_cols
        empty_col = num_labels % num_cols
        if num_rows > 1:
            axes[empty_row, empty_col].axis('off')
        else:
            axes[empty_col].axis('off')

    plt.show()

# Show one image per label for training set
show_one_image_per_label(X_train, y_train_labels)

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## Normalization
#
# - Convert lists to numpy arrays.
# - Standardize the pixel values of the images to have a mean of 0 and a standard deviation of 1 to stabilize the training process.
# - Leads to faster convergence during training and prevents any one feature from dominating the learning process.

# %%
# Convert list to numpy array and normalize pixel values of images 131x131
X_train = np.array(X_train, dtype=np.float32) / 255.0
X_test = np.array(X_test, dtype=np.float32) / 255.0
X_validation = np.array(X_validation, dtype=np.float32) / 255.0

# %% [markdown]
# ## One-Hot Encoding
#
# - Converts categorical labels into a binary matrix representation.
# - Ensures that the model treats each class as mutually exclusive, thus preventing it from assuming any ordinal relationship between the classes.

# %%
# # METHOD 1: Using Label Binarizer to directly binarize the labels
# from sklearn.preprocessing import LabelBinarizer

# # Initialize LabelBinarizer
# label_binarizer = LabelBinarizer()

# # Fit and transform labels for training data
# y_train_one_hot = label_binarizer.fit_transform(y_train_labels)

# # Transform labels for testing and validation data
# y_test_one_hot = label_binarizer.transform(y_test_labels)
# y_validation_one_hot = label_binarizer.transform(y_validation_labels)



# METHOD 2: Use label Encoder first to encode the labels as integers 
# then use to_categorical to convert into one-hot encoded vectors
encoder = LabelEncoder()

# Convert string labels to One-Hot Encoding
y_train_int = encoder.fit_transform(y_train_labels)
y_test_int = encoder.transform(y_test_labels) 
y_validation_int = encoder.transform(y_validation_labels)

# Convert integer encoded labels to one-hot encoded vectors
y_train = tf.keras.utils.to_categorical(y_train_int)
y_test = tf.keras.utils.to_categorical(y_test_int)
y_validation = tf.keras.utils.to_categorical(y_validation_int)

# %% [markdown]
# ## Data Visualization from original Data
# Counting number of images in each label
# - train: mixed number
# - test: 200 each
# - validation: 200 each
#
# Bar graph
# - To visualize the distribution of label within each dataset.
# -  helps to understand if the dataset is balanced or skewed towards certain classes.

# %%
# Count the number of class in each dataset
label_counts_train = Counter(y_train_labels)
label_counts_test = Counter(y_test_labels)
label_counts_validation = Counter(y_validation_labels)

# Display the counts
print("Training Label Counts:", label_counts_train,'\n')
print("Test Label Counts:", label_counts_test,'\n')
print("Validation Label Counts:", label_counts_validation)

# Bar graph
def plot_label_distribution(label_counts, dataset_name):
    labels = list(label_counts.keys())
    counts = list(label_counts.values())

    plt.figure(figsize=(10, 6))
    plt.bar(labels, counts, color='skyblue')
    plt.xlabel('Labels')
    plt.ylabel('Number of Images')
    plt.title(f'Label Distribution for {dataset_name}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Plot label distribution for training data
plot_label_distribution(label_counts_train, 'Training Data')

# Plot label distribution for test data
plot_label_distribution(label_counts_test, 'Test Data')

# Plot label distribution for validation data
plot_label_distribution(label_counts_validation, 'Validation Data')
# Out:
# Training Label Counts: Counter({'Tomato': 955, 'Brinjal': 868, 'Pumpkin': 814, 'Cucumber': 812, 'Bean': 780, 'Broccoli': 750, 'Bitter_Gourd': 720, 'Cauliflower': 587, 'Papaya': 566, 'Cabbage': 503, 'Bottle_Gourd': 441, 'Potato': 377, 'Capsicum': 351, 'Carrot': 256, 'Radish': 248})
#
# Test Label Counts: Counter({'Bean': 200, 'Bitter_Gourd': 200, 'Bottle_Gourd': 200, 'Brinjal': 200, 'Broccoli': 200, 'Cabbage': 200, 'Capsicum': 200, 'Carrot': 200, 'Cauliflower': 200, 'Cucumber': 200, 'Papaya': 200, 'Potato': 200, 'Pumpkin': 200, 'Radish': 200, 'Tomato': 200})
#
# Validation Label Counts: Counter({'Bean': 200, 'Bitter_Gourd': 200, 'Bottle_Gourd': 200, 'Brinjal': 200, 'Broccoli': 200, 'Cabbage': 200, 'Capsicum': 200, 'Carrot': 200, 'Cauliflower': 200, 'Cucumber': 200, 'Papaya': 200, 'Potato': 200, 'Pumpkin': 200, 'Radish': 200, 'Tomato': 200})

# %% [markdown]
# ## Data Augmentation
# - From the data visualization, we know that there is a class imbalance due to the different number of vegetable images.
# - Data augmentation is then used to artificially increase the size of the training dataset by applying various transformations.
# - Some transformations include: Rotation, Translation, Shearing, Scaling, Flipping, Contrast adjustment, Brightness adjustment, Noise addition.
# - We use a loop to find the class that does not reach our target number of images (1000). We then augment those images with different transformations to reach the target count.

# %%
# Create another variable so it doesnt change the original y_train_labels
y_train_labels_augmentation = y_train_labels.copy()

# Function to augment the new images into the training data
def augment_images(X_train, y_train_labels_augmentation, batch_size, target_count):
    
    # Find the distribution of labels
    distribution = Counter(y_train_labels_augmentation)
    
    # Use ImageDataGenerator with different augmentation options
    data_gen = ImageDataGenerator(
        rotation_range=15,            # Rotate by up to 15 degrees
        width_shift_range=0.1,        # Shift horizontally by up to 10% of the width
        height_shift_range=0.1,       # Shift vertically by up to 10% of the height
        shear_range=0.1,              # Shear angle in radians
        zoom_range=0.1,               # Zoom range [1-zoom_range, 1+zoom_range]
        horizontal_flip=True,         # Flip horizontally
        fill_mode='nearest',          # Fill mode for points outside the input boundaries
        brightness_range=[0.8, 1.2]   # Increases and decreases the brightness
    )

    # Add augment to classes with fewer image than the 1000
    for class_label, count in distribution.items():
        if count < target_count:
            # Calculate number of images needed to augment
            num_additional = target_count - count

            # Get indices of all occurrences of this class
            class_indices = np.where(np.array(y_train_labels) == class_label)[0]

            # Augment images until target count is reached
            for i in range(num_additional):
                # Choose random images from this class
                sample_indices = np.random.choice(class_indices, size=min(batch_size, num_additional), replace=False)
                sample_images = X_train[sample_indices]

                # Before augment: Expand image to include channel dimension
                sample_images = np.expand_dims(sample_images, axis=-1)  

                # Generate augmented images
                augmented_images = next(data_gen.flow(sample_images, batch_size=batch_size))

                # After augment: Remove the image channel dimension for grayscale
                augmented_images = np.squeeze(augmented_images, axis=-1)

                # Append augmented images and labels to the training set
                X_train = np.concatenate((X_train, augmented_images))
                y_train_labels_augmentation.extend([class_label] * augmented_images.shape[0])
                num_additional -= augmented_images.shape[0]

    # Reshape X_train
    X_train = X_train.reshape((-1, 131, 131, 1))

    return X_train, y_train_labels_augmentation

# Calling the function for 131x131
X_train_augmented, y_train_augmented = augment_images(X_train, y_train_labels_augmentation, batch_size=32, target_count=1000)

# Changing y_train_augmented back into encoded
label_binarizer = LabelBinarizer()
# Fit and transform the labels
y_train_augmented = label_binarizer.fit_transform(y_train_augmented)


# Visualizing the new distribution of the labels
label_counts_augmented = Counter(y_train_labels_augmentation)
plot_label_distribution(label_counts_augmented, 'Training Data')

# %% [markdown]
# # **CNN Model**

# %% [markdown]
# ## Simple CNN model before Data Augmentation

# %% [markdown]
# ### Modelling
# - 3 convolutional layers
# - 'relu' as the activation function because it introduces sparsity in the network which can help reduce the computational load and overfitting by providing a better selective representation of the images.
# - 'softmax' as the output activation function because it uses probability interpretation to convert the raw scores produced by the neural network into probabilities to find out what label the input belongs to.
#
#
# Reference:
# 1. https://www.analyticsvidhya.com/blog/2021/04/introduction-to-softmax-for-neural
# 2. https://medium.com/@sreeku.ralla/activation-functions-relu-vs-leaky-relu-b8272dc0b1be

# %%
# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.5))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))  
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=15, batch_size=64, verbose=1)
# Out:
# Epoch 1/15
# 142/142 [==============================] - 4s 28ms/step - loss: 2.4497 - accuracy: 0.1613 - val_loss: 2.2696 - val_accuracy: 0.2807
# Epoch 2/15
# 142/142 [==============================] - 4s 26ms/step - loss: 1.7793 - accuracy: 0.4204 - val_loss: 1.8297 - val_accuracy: 0.4050
# Epoch 3/15
# 142/142 [==============================] - 4s 26ms/step - loss: 1.3423 - accuracy: 0.5716 - val_loss: 1.3792 - val_accuracy: 0.5377
# Epoch 4/15
# 142/142 [==============================] - 4s 26ms/step - loss: 1.0863 - accuracy: 0.6554 - val_loss: 1.2355 - val_accuracy: 0.5963
# Epoch 5/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.8757 - accuracy: 0.7174 - val_loss: 0.7756 - val_accuracy: 0.7527
# Epoch 6/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.7565 - accuracy: 0.7613 - val_loss: 0.9767 - val_accuracy: 0.6777
# Epoch 7/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.5891 - accuracy: 0.8096 - val_loss: 0.7757 - val_accuracy: 0.7520
# Epoch 8/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.5734 - accuracy: 0.8177 - val_loss: 0.4794 - val_accuracy: 0.8590
# Epoch 9/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.4362 - accuracy: 0.8620 - val_loss: 0.3801 - val_accuracy: 0.8873
# Epoch 10/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.4092 - accuracy: 0.8648 - val_loss: 0.4141 - val_accuracy: 0.8797
# Epoch 11/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.3468 - accuracy: 0.8893 - val_loss: 0.3683 - val_accuracy: 0.8893
# Epoch 12/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.3299 - accuracy: 0.8920 - val_loss: 0.5244 - val_accuracy: 0.8340
# Epoch 13/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.3096 - accuracy: 0.8978 - val_loss: 0.3766 - val_accuracy: 0.8840
# Epoch 14/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.2489 - accuracy: 0.9185 - val_loss: 0.3578 - val_accuracy: 0.8840
# Epoch 15/15
# 142/142 [==============================] - 4s 26ms/step - loss: 0.2455 - accuracy: 0.9206 - val_loss: 0.3435 - val_accuracy: 0.8990

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_115"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_351 (Conv2D)         (None, 128, 128, 128)     2176
#
#  max_pooling2d_144 (MaxPooli  (None, 42, 42, 128)      0
#  ng2D)
#
#  dropout_288 (Dropout)       (None, 42, 42, 128)       0
#
#  conv2d_352 (Conv2D)         (None, 39, 39, 128)       262272
#
#  max_pooling2d_145 (MaxPooli  (None, 13, 13, 128)      0
#  ng2D)
#
#  dropout_289 (Dropout)       (None, 13, 13, 128)       0
#
#  conv2d_353 (Conv2D)         (None, 10, 10, 128)       262272
#
#  max_pooling2d_146 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  dropout_290 (Dropout)       (None, 3, 3, 128)         0
#
#  flatten_104 (Flatten)       (None, 1152)              0
#
#  dense_292 (Dense)           (None, 64)                73792
#
#  dense_293 (Dense)           (None, 15)                975
#
# =================================================================
# Total params: 601,487
# Trainable params: 601,487
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 1s 6ms/step - loss: 0.3333 - accuracy: 0.8973
#
# Test accuracy: 89.73%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.343474805355072
# Validation Accuracy: 0.8989999890327454

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 0s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.91      0.89      0.90       200
# Bitter_Gourd       0.97      0.90      0.93       200
# Bottle_Gourd       0.91      0.96      0.94       200
#      Brinjal       0.92      0.89      0.90       200
#     Broccoli       0.96      0.92      0.94       200
#      Cabbage       0.93      0.80      0.86       200
#     Capsicum       0.94      0.88      0.91       200
#       Carrot       0.79      0.93      0.86       200
#  Cauliflower       0.87      0.94      0.90       200
#     Cucumber       0.92      0.93      0.92       200
#       Papaya       0.88      0.90      0.89       200
#       Potato       0.85      0.90      0.88       200
#      Pumpkin       0.90      0.95      0.93       200
#       Radish       0.92      0.80      0.86       200
#       Tomato       0.82      0.89      0.85       200
#
#     accuracy                           0.90      3000
#    macro avg       0.90      0.90      0.90      3000
# weighted avg       0.90      0.90      0.90      3000

# %% [markdown]
# ## Simple CNN model after Data Augmentation

# %% [markdown]
# ### Modelling
#
# Explanation
# - Increased dataset size after Data Augmentation. Each label contains 200 images of each vegetable.
# - This helps to prevent bias image training and regularize the images so that the model will learn more generalizable features.

# %%
# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.5))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))  
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

history = model.fit(X_train_augmented, y_train_augmented, validation_data=(X_validation, y_validation),
          epochs=15, batch_size=64, verbose=1)
# Out:
# Epoch 1/15
# 235/235 [==============================] - 6s 25ms/step - loss: 2.4900 - accuracy: 0.1485 - val_loss: 2.0952 - val_accuracy: 0.3100
# Epoch 2/15
# 235/235 [==============================] - 6s 24ms/step - loss: 2.0570 - accuracy: 0.3135 - val_loss: 1.6880 - val_accuracy: 0.4577
# Epoch 3/15
# 235/235 [==============================] - 6s 24ms/step - loss: 1.7695 - accuracy: 0.4127 - val_loss: 1.3926 - val_accuracy: 0.5457
# Epoch 4/15
# 235/235 [==============================] - 6s 26ms/step - loss: 1.5883 - accuracy: 0.4706 - val_loss: 0.7938 - val_accuracy: 0.7517
# Epoch 5/15
# 235/235 [==============================] - 6s 26ms/step - loss: 1.4471 - accuracy: 0.5184 - val_loss: 0.6867 - val_accuracy: 0.7843
# Epoch 6/15
# 235/235 [==============================] - 6s 25ms/step - loss: 1.3466 - accuracy: 0.5418 - val_loss: 0.5220 - val_accuracy: 0.8407
# Epoch 7/15
# 235/235 [==============================] - 6s 26ms/step - loss: 1.2962 - accuracy: 0.5619 - val_loss: 0.5994 - val_accuracy: 0.8063
# Epoch 8/15
# 235/235 [==============================] - 6s 26ms/step - loss: 1.2388 - accuracy: 0.5790 - val_loss: 0.5005 - val_accuracy: 0.8397
# Epoch 9/15
# 235/235 [==============================] - 6s 25ms/step - loss: 1.2050 - accuracy: 0.5920 - val_loss: 0.5065 - val_accuracy: 0.8467
# Epoch 10/15
# 235/235 [==============================] - 6s 25ms/step - loss: 1.1939 - accuracy: 0.5925 - val_loss: 0.3956 - val_accuracy: 0.8837
# Epoch 11/15
# 235/235 [==============================] - 6s 25ms/step - loss: 1.1623 - accuracy: 0.6025 - val_loss: 0.4348 - val_accuracy: 0.8707
# Epoch 12/15
# 235/235 [==============================] - 6s 25ms/step - loss: 1.1512 - accuracy: 0.6066 - val_loss: 0.3682 - val_accuracy: 0.8913
# Epoch 13/15
# 235/235 [==============================] - 6s 26ms/step - loss: 1.1256 - accuracy: 0.6137 - val_loss: 0.3454 - val_accuracy: 0.8987
# Epoch 14/15
# 235/235 [==============================] - 6s 24ms/step - loss: 1.1061 - accuracy: 0.6213 - val_loss: 0.3615 - val_accuracy: 0.8993
# Epoch 15/15
# 235/235 [==============================] - 6s 24ms/step - loss: 1.1089 - accuracy: 0.6234 - val_loss: 0.3418 - val_accuracy: 0.9020

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_116"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_354 (Conv2D)         (None, 128, 128, 128)     2176
#
#  max_pooling2d_147 (MaxPooli  (None, 42, 42, 128)      0
#  ng2D)
#
#  dropout_291 (Dropout)       (None, 42, 42, 128)       0
#
#  conv2d_355 (Conv2D)         (None, 39, 39, 128)       262272
#
#  max_pooling2d_148 (MaxPooli  (None, 13, 13, 128)      0
#  ng2D)
#
#  dropout_292 (Dropout)       (None, 13, 13, 128)       0
#
#  conv2d_356 (Conv2D)         (None, 10, 10, 128)       262272
#
#  max_pooling2d_149 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  dropout_293 (Dropout)       (None, 3, 3, 128)         0
#
#  flatten_105 (Flatten)       (None, 1152)              0
#
#  dense_294 (Dense)           (None, 64)                73792
#
#  dense_295 (Dense)           (None, 15)                975
#
# =================================================================
# Total params: 601,487
# Trainable params: 601,487
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2875 - accuracy: 0.9127
#
# Test accuracy: 91.27%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.3418194055557251
# Validation Accuracy: 0.9020000100135803

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 0s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       200
#            1       0.97      0.93      0.95       200
#            2       0.93      0.96      0.94       200
#            3       0.84      0.94      0.89       200
#            4       0.96      0.96      0.96       200
#            5       0.88      0.94      0.91       200
#            6       0.92      0.94      0.93       200
#            7       0.94      0.77      0.85       200
#            8       0.93      0.93      0.93       200
#            9       0.83      0.98      0.90       200
#           10       0.90      0.94      0.92       200
#           11       0.89      0.82      0.86       200
#           12       0.96      0.94      0.95       200
#           13       0.99      0.78      0.87       200
#           14       0.84      0.92      0.88       200
#
#     accuracy                           0.91      3000
#    macro avg       0.92      0.91      0.91      3000
# weighted avg       0.92      0.91      0.91      3000

# %% [markdown]
# ## Trying to add Batch normalization

# %% [markdown]
# ### Modelling
#
# Batch Normalization Explanation
# - It speeds up learning as it reduces internal covariate shifts which helps the model train faster.
# - It adds a little noise to the model and therefore, regularization techniques such as dropout is not neccessary.
# - It helps to us much larger learning rates, hence speeding up the training process.
#
# Reference: https://www.analyticsvidhya.com/blog/2021/03/introduction-to-batch-normalization/

# %%
from tensorflow.keras.layers import BatchNormalization

# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3)))  
model.add(Flatten())
model.add(Dense(64, activation='relu')) 
model.add(BatchNormalization())
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=15, batch_size=64, verbose=1)
# Out:
# Epoch 1/15
# 142/142 [==============================] - 7s 43ms/step - loss: 1.4931 - accuracy: 0.5459 - val_loss: 6.3976 - val_accuracy: 0.0840
# Epoch 2/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.6694 - accuracy: 0.7931 - val_loss: 8.0113 - val_accuracy: 0.0800
# Epoch 3/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.4117 - accuracy: 0.8748 - val_loss: 5.5302 - val_accuracy: 0.1883
# Epoch 4/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.2207 - accuracy: 0.9330 - val_loss: 3.0368 - val_accuracy: 0.3477
# Epoch 5/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.1946 - accuracy: 0.9425 - val_loss: 1.4730 - val_accuracy: 0.6497
# Epoch 6/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.1061 - accuracy: 0.9694 - val_loss: 1.1572 - val_accuracy: 0.7070
# Epoch 7/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.1197 - accuracy: 0.9639 - val_loss: 6.2540 - val_accuracy: 0.2860
# Epoch 8/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.0295 - accuracy: 0.9936 - val_loss: 1.0798 - val_accuracy: 0.7620
# Epoch 9/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.0305 - accuracy: 0.9925 - val_loss: 1.2268 - val_accuracy: 0.7010
# Epoch 10/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.1555 - accuracy: 0.9506 - val_loss: 0.7804 - val_accuracy: 0.7767
# Epoch 11/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.0611 - accuracy: 0.9805 - val_loss: 3.4277 - val_accuracy: 0.5147
# Epoch 12/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.0798 - accuracy: 0.9764 - val_loss: 0.7483 - val_accuracy: 0.8130
# Epoch 13/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.0168 - accuracy: 0.9959 - val_loss: 0.3183 - val_accuracy: 0.9200
# Epoch 14/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 7.1803 - val_accuracy: 0.3287
# Epoch 15/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.0627 - accuracy: 0.9802 - val_loss: 0.6566 - val_accuracy: 0.8330

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_138"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_420 (Conv2D)         (None, 128, 128, 128)     2176
#
#  batch_normalization_21 (Bat  (None, 128, 128, 128)    512
#  chNormalization)
#
#  max_pooling2d_186 (MaxPooli  (None, 42, 42, 128)      0
#  ng2D)
#
#  conv2d_421 (Conv2D)         (None, 39, 39, 128)       262272
#
#  batch_normalization_22 (Bat  (None, 39, 39, 128)      512
#  chNormalization)
#
#  max_pooling2d_187 (MaxPooli  (None, 13, 13, 128)      0
#  ng2D)
#
#  conv2d_422 (Conv2D)         (None, 10, 10, 128)       262272
#
#  batch_normalization_23 (Bat  (None, 10, 10, 128)      512
#  chNormalization)
#
#  max_pooling2d_188 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  flatten_125 (Flatten)       (None, 1152)              0
#
#  dense_338 (Dense)           (None, 64)                73792
#
#  dense_339 (Dense)           (None, 15)                975
#
# =================================================================
# Total params: 603,023
# Trainable params: 602,255
# Non-trainable params: 768
# _________________________________________________________________
# 94/94 [==============================] - 1s 7ms/step - loss: 0.6175 - accuracy: 0.8357
#
# Test accuracy: 83.57%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.6566247940063477
# Validation Accuracy: 0.8330000042915344

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 1s 5ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.94      0.88      0.91       200
# Bitter_Gourd       0.83      0.95      0.89       200
# Bottle_Gourd       0.96      0.91      0.93       200
#      Brinjal       0.81      0.85      0.83       200
#     Broccoli       0.97      0.79      0.87       200
#      Cabbage       0.83      0.51      0.63       200
#     Capsicum       0.84      0.95      0.89       200
#       Carrot       0.94      0.88      0.91       200
#  Cauliflower       0.62      0.96      0.75       200
#     Cucumber       0.93      0.86      0.90       200
#       Papaya       0.99      0.71      0.83       200
#       Potato       0.89      0.81      0.85       200
#      Pumpkin       0.54      0.99      0.70       200
#       Radish       0.99      0.73      0.84       200
#       Tomato       0.99      0.73      0.84       200
#
#     accuracy                           0.84      3000
#    macro avg       0.87      0.84      0.84      3000
# weighted avg       0.87      0.84      0.84      3000

# %% [markdown]
# ## Trying to add Earlystopping and Modelcheckpoint

# %% [markdown]
# ### Modelling
#
# Early Stopping Explanation
# - It is important for situations to reduce overfitting and increase the model's performance on any general datasset.
# - It takes less time compared to other regularisation models and its easy to implement.
# - It calculates the loss to epoch and will stop when the loss starts to increase again.
# - min_delta parameter allows you to set a threshold for the magnitude of change in the metric.
# - patience parameter determines the number of epochs to wait before considering stopping.
#
# Model Checkpoint Explanation
# - Captures the weights of the model during training
# - It automatically saves the model weights whenever the quantity is optimum when compared to last epoch/batch
#
# Reference
# 1. https://www.geeksforgeeks.org/regularization-by-early-stopping/
# 2. https://medium.com/swlh/a-high-level-overview-of-keras-modelcheckpoint-callback-deae8099d786

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.5))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))  
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=4, min_delta=0.001)

# Define ModelCheckpoint callback
model_checkpoint = ModelCheckpoint(filepath='best_model_131.h5', monitor='val_accuracy', save_best_only=True)

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=20, batch_size=64, verbose=1, callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/20
# 142/142 [==============================] - 4s 27ms/step - loss: 2.5167 - accuracy: 0.1358 - val_loss: 2.3298 - val_accuracy: 0.1980
# Epoch 2/20
# 142/142 [==============================] - 4s 26ms/step - loss: 1.9349 - accuracy: 0.3675 - val_loss: 1.8183 - val_accuracy: 0.3747
# Epoch 3/20
# 142/142 [==============================] - 4s 26ms/step - loss: 1.4469 - accuracy: 0.5346 - val_loss: 1.4590 - val_accuracy: 0.5230
# Epoch 4/20
# 142/142 [==============================] - 4s 26ms/step - loss: 1.0853 - accuracy: 0.6450 - val_loss: 0.9814 - val_accuracy: 0.6880
# Epoch 5/20
# 142/142 [==============================] - 4s 26ms/step - loss: 0.8691 - accuracy: 0.7229 - val_loss: 0.7796 - val_accuracy: 0.7523
# Epoch 6/20
# 142/142 [==============================] - 4s 26ms/step - loss: 0.6909 - accuracy: 0.7745 - val_loss: 0.6631 - val_accuracy: 0.7840
# Epoch 7/20
# 142/142 [==============================] - 4s 27ms/step - loss: 0.5823 - accuracy: 0.8129 - val_loss: 0.5471 - val_accuracy: 0.8313
# Epoch 8/20
# 142/142 [==============================] - 4s 26ms/step - loss: 0.4864 - accuracy: 0.8439 - val_loss: 0.5218 - val_accuracy: 0.8290
# Epoch 9/20
# 142/142 [==============================] - 4s 27ms/step - loss: 0.4054 - accuracy: 0.8717 - val_loss: 0.4169 - val_accuracy: 0.8700
# Epoch 10/20
# 142/142 [==============================] - 4s 26ms/step - loss: 0.3562 - accuracy: 0.8903 - val_loss: 0.4970 - val_accuracy: 0.8413
# Epoch 11/20
# 142/142 [==============================] - 4s 25ms/step - loss: 0.3266 - accuracy: 0.8934 - val_loss: 0.6690 - val_accuracy: 0.7877
# Epoch 12/20
# 142/142 [==============================] - 4s 25ms/step - loss: 0.3600 - accuracy: 0.8829 - val_loss: 0.4482 - val_accuracy: 0.8580
# Epoch 13/20
# 142/142 [==============================] - 4s 25ms/step - loss: 0.2630 - accuracy: 0.9109 - val_loss: 0.3367 - val_accuracy: 0.9003
# Epoch 14/20
# 142/142 [==============================] - 4s 25ms/step - loss: 0.2397 - accuracy: 0.9214 - val_loss: 0.3889 - val_accuracy: 0.8807
# Epoch 15/20
# 142/142 [==============================] - 4s 25ms/step - loss: 0.2071 - accuracy: 0.9293 - val_loss: 0.2870 - val_accuracy: 0.9157
# Epoch 16/20
# 142/142 [==============================] - 4s 27ms/step - loss: 0.1903 - accuracy: 0.9365 - val_loss: 0.3527 - val_accuracy: 0.8950
# Epoch 17/20
# 142/142 [==============================] - 4s 28ms/step - loss: 0.1777 - accuracy: 0.9407 - val_loss: 0.2663 - val_accuracy: 0.9220
# Epoch 18/20
# 142/142 [==============================] - 4s 28ms/step - loss: 0.1612 - accuracy: 0.9467 - val_loss: 0.2616 - val_accuracy: 0.9267
# Epoch 19/20
# 142/142 [==============================] - 4s 27ms/step - loss: 0.1574 - accuracy: 0.9484 - val_loss: 0.2742 - val_accuracy: 0.9213
# Epoch 20/20
# 142/142 [==============================] - 4s 27ms/step - loss: 0.1510 - accuracy: 0.9498 - val_loss: 0.2763 - val_accuracy: 0.9237

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_134"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_408 (Conv2D)         (None, 128, 128, 128)     2176
#
#  max_pooling2d_177 (MaxPooli  (None, 42, 42, 128)      0
#  ng2D)
#
#  dropout_321 (Dropout)       (None, 42, 42, 128)       0
#
#  conv2d_409 (Conv2D)         (None, 39, 39, 128)       262272
#
#  max_pooling2d_178 (MaxPooli  (None, 13, 13, 128)      0
#  ng2D)
#
#  dropout_322 (Dropout)       (None, 13, 13, 128)       0
#
#  conv2d_410 (Conv2D)         (None, 10, 10, 128)       262272
#
#  max_pooling2d_179 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  dropout_323 (Dropout)       (None, 3, 3, 128)         0
#
#  flatten_121 (Flatten)       (None, 1152)              0
#
#  dense_330 (Dense)           (None, 64)                73792
#
#  dense_331 (Dense)           (None, 15)                975
#
# =================================================================
# Total params: 601,487
# Trainable params: 601,487
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2582 - accuracy: 0.9227
#
# Test accuracy: 92.27%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.27632156014442444
# Validation Accuracy: 0.9236666560173035

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 0s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.93      0.94      0.93       200
# Bitter_Gourd       0.99      0.91      0.95       200
# Bottle_Gourd       0.90      0.99      0.94       200
#      Brinjal       0.92      0.95      0.93       200
#     Broccoli       0.95      0.96      0.95       200
#      Cabbage       0.94      0.92      0.93       200
#     Capsicum       0.90      0.92      0.91       200
#       Carrot       0.97      0.78      0.87       200
#  Cauliflower       0.94      0.96      0.95       200
#     Cucumber       0.88      0.97      0.92       200
#       Papaya       0.89      0.94      0.91       200
#       Potato       0.90      0.86      0.88       200
#      Pumpkin       0.90      0.98      0.94       200
#       Radish       0.96      0.86      0.91       200
#       Tomato       0.92      0.91      0.91       200
#
#     accuracy                           0.92      3000
#    macro avg       0.92      0.92      0.92      3000
# weighted avg       0.92      0.92      0.92      3000

# %% [markdown]
# ## Trying AveragePooling2D instead of MaxPooling2D

# %% [markdown]
# ### Modelling
#
# Explanation
# - The average value of all the pixels in the batch is selected.
# - Compared to MaxPooling2D, AveragePooling2D is less sensitive to small variations and noise in the input data.
# - Finding the average value of a group of pixels can help to capture the general presence of a feature in a larger region.
#
# Reference: https://www.quora.com/What-is-the-benefit-of-using-average-pooling-rather-than-max-pooling

# %%
from keras.layers import AveragePooling2D
# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation='relu'))
model.add(AveragePooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.5))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(AveragePooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(AveragePooling2D(pool_size=(3, 3)))  
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=30, batch_size=64, verbose=1)
# Out:
# Epoch 1/30
# 142/142 [==============================] - 4s 28ms/step - loss: 2.5339 - accuracy: 0.1618 - val_loss: 2.4750 - val_accuracy: 0.1737
# Epoch 2/30
# 142/142 [==============================] - 4s 28ms/step - loss: 1.9976 - accuracy: 0.3552 - val_loss: 2.0424 - val_accuracy: 0.3547
# Epoch 3/30
# 142/142 [==============================] - 4s 29ms/step - loss: 1.6963 - accuracy: 0.4524 - val_loss: 1.7859 - val_accuracy: 0.4353
# Epoch 4/30
# 142/142 [==============================] - 4s 29ms/step - loss: 1.4903 - accuracy: 0.5153 - val_loss: 1.4144 - val_accuracy: 0.5390
# Epoch 5/30
# 142/142 [==============================] - 4s 27ms/step - loss: 1.2904 - accuracy: 0.5872 - val_loss: 1.2777 - val_accuracy: 0.5900
# Epoch 6/30
# 142/142 [==============================] - 4s 28ms/step - loss: 1.1668 - accuracy: 0.6284 - val_loss: 1.2002 - val_accuracy: 0.6093
# Epoch 7/30
# 142/142 [==============================] - 4s 28ms/step - loss: 1.0442 - accuracy: 0.6695 - val_loss: 1.0996 - val_accuracy: 0.6563
# Epoch 8/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.9110 - accuracy: 0.7113 - val_loss: 0.9401 - val_accuracy: 0.7020
# Epoch 9/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.8199 - accuracy: 0.7431 - val_loss: 0.8587 - val_accuracy: 0.7413
# Epoch 10/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.7995 - accuracy: 0.7404 - val_loss: 0.8228 - val_accuracy: 0.7503
# Epoch 11/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.7176 - accuracy: 0.7736 - val_loss: 0.7114 - val_accuracy: 0.7910
# Epoch 12/30
# 142/142 [==============================] - 4s 27ms/step - loss: 0.6667 - accuracy: 0.7870 - val_loss: 0.6338 - val_accuracy: 0.8153
# Epoch 13/30
# 142/142 [==============================] - 4s 27ms/step - loss: 0.5810 - accuracy: 0.8145 - val_loss: 0.6827 - val_accuracy: 0.7913
# Epoch 14/30
# 142/142 [==============================] - 4s 27ms/step - loss: 0.5483 - accuracy: 0.8244 - val_loss: 0.5983 - val_accuracy: 0.8180
# Epoch 15/30
# 142/142 [==============================] - 4s 26ms/step - loss: 0.5148 - accuracy: 0.8299 - val_loss: 0.6065 - val_accuracy: 0.8230
# Epoch 16/30
# 142/142 [==============================] - 4s 27ms/step - loss: 0.4843 - accuracy: 0.8428 - val_loss: 0.5064 - val_accuracy: 0.8577
# Epoch 17/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.4317 - accuracy: 0.8572 - val_loss: 0.5203 - val_accuracy: 0.8543
# Epoch 18/30
# 142/142 [==============================] - 4s 29ms/step - loss: 0.3958 - accuracy: 0.8743 - val_loss: 0.4837 - val_accuracy: 0.8667
# Epoch 19/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.3669 - accuracy: 0.8819 - val_loss: 0.5650 - val_accuracy: 0.8373
# Epoch 20/30
# 142/142 [==============================] - 4s 27ms/step - loss: 0.3614 - accuracy: 0.8783 - val_loss: 0.5264 - val_accuracy: 0.8527
# Epoch 21/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.3482 - accuracy: 0.8860 - val_loss: 0.4987 - val_accuracy: 0.8600
# Epoch 22/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.3161 - accuracy: 0.8949 - val_loss: 0.5603 - val_accuracy: 0.8433
# Epoch 23/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.3108 - accuracy: 0.8972 - val_loss: 0.4649 - val_accuracy: 0.8683
# Epoch 24/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.2911 - accuracy: 0.9041 - val_loss: 0.4973 - val_accuracy: 0.8640
# Epoch 25/30
# 142/142 [==============================] - 4s 27ms/step - loss: 0.3154 - accuracy: 0.8937 - val_loss: 0.4428 - val_accuracy: 0.8803
# Epoch 26/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.2522 - accuracy: 0.9188 - val_loss: 0.4772 - val_accuracy: 0.8707
# Epoch 27/30
# 142/142 [==============================] - 4s 29ms/step - loss: 0.2511 - accuracy: 0.9156 - val_loss: 0.4471 - val_accuracy: 0.8807
# Epoch 28/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.2379 - accuracy: 0.9222 - val_loss: 0.4980 - val_accuracy: 0.8607
# Epoch 29/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.2236 - accuracy: 0.9259 - val_loss: 0.4479 - val_accuracy: 0.8853
# Epoch 30/30
# 142/142 [==============================] - 4s 28ms/step - loss: 0.2139 - accuracy: 0.9270 - val_loss: 0.4360 - val_accuracy: 0.8910

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_119"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_363 (Conv2D)         (None, 128, 128, 128)     2176
#
#  average_pooling2d_18 (Avera  (None, 42, 42, 128)      0
#  gePooling2D)
#
#  dropout_297 (Dropout)       (None, 42, 42, 128)       0
#
#  conv2d_364 (Conv2D)         (None, 39, 39, 128)       262272
#
#  average_pooling2d_19 (Avera  (None, 13, 13, 128)      0
#  gePooling2D)
#
#  dropout_298 (Dropout)       (None, 13, 13, 128)       0
#
#  conv2d_365 (Conv2D)         (None, 10, 10, 128)       262272
#
#  average_pooling2d_20 (Avera  (None, 3, 3, 128)        0
#  gePooling2D)
#
#  dropout_299 (Dropout)       (None, 3, 3, 128)         0
#
#  flatten_108 (Flatten)       (None, 1152)              0
#
#  dense_300 (Dense)           (None, 64)                73792
#
#  dense_301 (Dense)           (None, 15)                975
#
# =================================================================
# Total params: 601,487
# Trainable params: 601,487
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 1s 6ms/step - loss: 0.3644 - accuracy: 0.8960
#
# Test accuracy: 89.60%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.4360201358795166
# Validation Accuracy: 0.890999972820282

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 0s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.85      0.97      0.91       200
# Bitter_Gourd       0.92      0.94      0.93       200
# Bottle_Gourd       0.95      0.99      0.97       200
#      Brinjal       0.94      0.95      0.94       200
#     Broccoli       0.88      0.88      0.88       200
#      Cabbage       0.96      0.76      0.84       200
#     Capsicum       0.93      0.88      0.90       200
#       Carrot       0.81      0.93      0.87       200
#  Cauliflower       0.89      0.90      0.90       200
#     Cucumber       0.94      0.93      0.93       200
#       Papaya       0.92      0.90      0.91       200
#       Potato       0.91      0.82      0.86       200
#      Pumpkin       0.86      0.92      0.89       200
#       Radish       0.95      0.87      0.91       200
#       Tomato       0.79      0.82      0.81       200
#
#     accuracy                           0.90      3000
#    macro avg       0.90      0.90      0.90      3000
# weighted avg       0.90      0.90      0.90      3000

# %% [markdown]
# ## Trying Dilated Convolution instead of MaxPooling2D

# %% [markdown]
# ### Modelling
#
# Explaination
# - Dilated convolutions helps to expand the area of the input image covered without pooling. The objective is to cover more information about the image from the output obtained with every convolution operation.
# - It increases receptive field without increasing parameters.
# - It can capture features at multiple scales.
# - It reduced spatial resolution loss compared to regular convolutions with larger filters.
#
# Reference:
# https://www.geeksforgeeks.org/dilated-convolution/

# %%
# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), dilation_rate=(2, 2), input_shape=(131, 131, 1), activation='relu'))
model.add(MaxPooling2D(3, 3))
model.add(Dropout(0.25))
model.add(Conv2D(128,(4, 4), dilation_rate=(2, 2), activation='relu'))
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), dilation_rate=(2, 2), activation='relu'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=15, batch_size=64, verbose=1)
# Out:
# Epoch 1/15
# 142/142 [==============================] - 7s 42ms/step - loss: 2.5164 - accuracy: 0.1533 - val_loss: 2.4740 - val_accuracy: 0.1850
# Epoch 2/15
# 142/142 [==============================] - 5s 38ms/step - loss: 2.0200 - accuracy: 0.3505 - val_loss: 2.7423 - val_accuracy: 0.1813
# Epoch 3/15
# 142/142 [==============================] - 6s 40ms/step - loss: 1.7150 - accuracy: 0.4558 - val_loss: 1.8489 - val_accuracy: 0.4020
# Epoch 4/15
# 142/142 [==============================] - 6s 39ms/step - loss: 1.2997 - accuracy: 0.5884 - val_loss: 1.3240 - val_accuracy: 0.5733
# Epoch 5/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.9840 - accuracy: 0.6901 - val_loss: 1.2978 - val_accuracy: 0.6077
# Epoch 6/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.7651 - accuracy: 0.7573 - val_loss: 1.7531 - val_accuracy: 0.5050
# Epoch 7/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.6763 - accuracy: 0.7884 - val_loss: 0.9782 - val_accuracy: 0.7167
# Epoch 8/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.4742 - accuracy: 0.8508 - val_loss: 0.7964 - val_accuracy: 0.7700
# Epoch 9/15
# 142/142 [==============================] - 5s 37ms/step - loss: 0.4298 - accuracy: 0.8635 - val_loss: 1.1193 - val_accuracy: 0.7053
# Epoch 10/15
# 142/142 [==============================] - 5s 37ms/step - loss: 0.3533 - accuracy: 0.8846 - val_loss: 0.8385 - val_accuracy: 0.7740
# Epoch 11/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.2455 - accuracy: 0.9251 - val_loss: 0.8011 - val_accuracy: 0.8067
# Epoch 12/15
# 142/142 [==============================] - 6s 39ms/step - loss: 0.1981 - accuracy: 0.9373 - val_loss: 1.0187 - val_accuracy: 0.7643
# Epoch 13/15
# 142/142 [==============================] - 5s 39ms/step - loss: 0.1948 - accuracy: 0.9374 - val_loss: 0.8932 - val_accuracy: 0.8030
# Epoch 14/15
# 142/142 [==============================] - 6s 39ms/step - loss: 0.1480 - accuracy: 0.9516 - val_loss: 0.9809 - val_accuracy: 0.7907
# Epoch 15/15
# 142/142 [==============================] - 5s 38ms/step - loss: 0.1209 - accuracy: 0.9617 - val_loss: 0.8839 - val_accuracy: 0.8213

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 125, 125, 128)     2176
#
#  max_pooling2d_8 (MaxPooling  (None, 41, 41, 128)      0
#  2D)
#
#  dropout_21 (Dropout)        (None, 41, 41, 128)       0
#
#  conv2d_28 (Conv2D)          (None, 35, 35, 128)       262272
#
#  dropout_22 (Dropout)        (None, 35, 35, 128)       0
#
#  conv2d_29 (Conv2D)          (None, 29, 29, 128)       262272
#
#  dropout_23 (Dropout)        (None, 29, 29, 128)       0
#
#  flatten_9 (Flatten)         (None, 107648)            0
#
#  dense_18 (Dense)            (None, 64)                6889536
#
#  dense_19 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 7,417,231
# Trainable params: 7,417,231
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 1s 8ms/step - loss: 0.7954 - accuracy: 0.8173
#
# Test accuracy: 81.73%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.8839185237884521
# Validation Accuracy: 0.8213333487510681

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 1s 6ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.81      0.91      0.85       200
# Bitter_Gourd       0.87      0.88      0.87       200
# Bottle_Gourd       0.78      0.91      0.84       200
#      Brinjal       0.80      0.80      0.80       200
#     Broccoli       0.79      0.89      0.83       200
#      Cabbage       0.87      0.74      0.80       200
#     Capsicum       0.89      0.77      0.82       200
#       Carrot       0.76      0.72      0.74       200
#  Cauliflower       0.81      0.79      0.80       200
#     Cucumber       0.87      0.83      0.85       200
#       Papaya       0.84      0.85      0.85       200
#       Potato       0.75      0.81      0.78       200
#      Pumpkin       0.89      0.85      0.87       200
#       Radish       0.85      0.69      0.76       200
#       Tomato       0.73      0.83      0.78       200
#
#     accuracy                           0.82      3000
#    macro avg       0.82      0.82      0.82      3000
# weighted avg       0.82      0.82      0.82      3000

# %% [markdown]
# ## Trying Strided Convolution instead of MaxPooling2D

# %% [markdown]
# ### Modelling
#
# Explanation
# - By a larger stride, the number of convolutions can be reduced. It helps to reduce the computational requirements.
# - Therefore it can help control the level of abstraction at which the CNN learns feactures
#
# Reference: https://www.naukri.com/code360/library/stride-in-convolutional-neural-network

# %%
# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), strides=(3, 3), input_shape=(131, 131, 1), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128, (4, 4), strides=(3, 3), activation='relu'))
model.add(Conv2D(128, (4, 4), strides=(3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=30, batch_size=64, verbose=1)
# Out:
# Epoch 1/30
# 142/142 [==============================] - 2s 10ms/step - loss: 2.5104 - accuracy: 0.1605 - val_loss: 2.3931 - val_accuracy: 0.1993
# Epoch 2/30
# 142/142 [==============================] - 1s 9ms/step - loss: 2.1085 - accuracy: 0.3113 - val_loss: 2.1222 - val_accuracy: 0.3047
# Epoch 3/30
# 142/142 [==============================] - 1s 9ms/step - loss: 1.8390 - accuracy: 0.3948 - val_loss: 1.8351 - val_accuracy: 0.3913
# Epoch 4/30
# 142/142 [==============================] - 1s 8ms/step - loss: 1.6210 - accuracy: 0.4777 - val_loss: 1.6813 - val_accuracy: 0.4440
# Epoch 5/30
# 142/142 [==============================] - 1s 9ms/step - loss: 1.4384 - accuracy: 0.5373 - val_loss: 1.4370 - val_accuracy: 0.5320
# Epoch 6/30
# 142/142 [==============================] - 1s 8ms/step - loss: 1.2671 - accuracy: 0.5892 - val_loss: 1.7513 - val_accuracy: 0.4227
# Epoch 7/30
# 142/142 [==============================] - 1s 9ms/step - loss: 1.1564 - accuracy: 0.6278 - val_loss: 1.4270 - val_accuracy: 0.5313
# Epoch 8/30
# 142/142 [==============================] - 1s 8ms/step - loss: 1.0271 - accuracy: 0.6727 - val_loss: 1.2137 - val_accuracy: 0.6267
# Epoch 9/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.9176 - accuracy: 0.7118 - val_loss: 1.2135 - val_accuracy: 0.6110
# Epoch 10/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.8062 - accuracy: 0.7440 - val_loss: 1.0867 - val_accuracy: 0.6617
# Epoch 11/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.7572 - accuracy: 0.7641 - val_loss: 1.1179 - val_accuracy: 0.6403
# Epoch 12/30
# 142/142 [==============================] - 1s 9ms/step - loss: 0.6848 - accuracy: 0.7871 - val_loss: 0.9907 - val_accuracy: 0.6893
# Epoch 13/30
# 142/142 [==============================] - 1s 9ms/step - loss: 0.5795 - accuracy: 0.8190 - val_loss: 1.0130 - val_accuracy: 0.6847
# Epoch 14/30
# 142/142 [==============================] - 1s 9ms/step - loss: 0.5360 - accuracy: 0.8315 - val_loss: 1.1824 - val_accuracy: 0.6383
# Epoch 15/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.4911 - accuracy: 0.8445 - val_loss: 1.1914 - val_accuracy: 0.6543
# Epoch 16/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.4944 - accuracy: 0.8439 - val_loss: 0.9850 - val_accuracy: 0.7113
# Epoch 17/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.3752 - accuracy: 0.8841 - val_loss: 1.0414 - val_accuracy: 0.7053
# Epoch 18/30
# 142/142 [==============================] - 1s 9ms/step - loss: 0.4157 - accuracy: 0.8672 - val_loss: 0.9808 - val_accuracy: 0.7087
# Epoch 19/30
# 142/142 [==============================] - 1s 9ms/step - loss: 0.3134 - accuracy: 0.9016 - val_loss: 0.9367 - val_accuracy: 0.7270
# Epoch 20/30
# 142/142 [==============================] - 1s 9ms/step - loss: 0.2873 - accuracy: 0.9095 - val_loss: 1.0196 - val_accuracy: 0.7190
# Epoch 21/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.2565 - accuracy: 0.9209 - val_loss: 1.1525 - val_accuracy: 0.6970
# Epoch 22/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.2123 - accuracy: 0.9338 - val_loss: 0.9759 - val_accuracy: 0.7533
# Epoch 23/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.1702 - accuracy: 0.9515 - val_loss: 1.0751 - val_accuracy: 0.7337
# Epoch 24/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.1590 - accuracy: 0.9546 - val_loss: 1.4213 - val_accuracy: 0.6823
# Epoch 25/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.1408 - accuracy: 0.9609 - val_loss: 1.1098 - val_accuracy: 0.7520
# Epoch 26/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.1236 - accuracy: 0.9656 - val_loss: 1.2087 - val_accuracy: 0.7257
# Epoch 27/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.1595 - accuracy: 0.9504 - val_loss: 1.2424 - val_accuracy: 0.7363
# Epoch 28/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.1923 - accuracy: 0.9415 - val_loss: 1.0744 - val_accuracy: 0.7433
# Epoch 29/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.0692 - accuracy: 0.9843 - val_loss: 1.1531 - val_accuracy: 0.7517
# Epoch 30/30
# 142/142 [==============================] - 1s 8ms/step - loss: 0.0682 - accuracy: 0.9840 - val_loss: 1.1156 - val_accuracy: 0.7683

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 43, 43, 128)       2176
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 128)         262272
#
#  conv2d_8 (Conv2D)           (None, 1, 1, 128)         262272
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 535,951
# Trainable params: 535,951
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 0s 4ms/step - loss: 1.0353 - accuracy: 0.7787
#
# Test accuracy: 77.87%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 1.115553379058838
# Validation Accuracy: 0.7683333158493042

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 0s 2ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.77      0.86      0.81       200
# Bitter_Gourd       0.77      0.87      0.82       200
# Bottle_Gourd       0.81      0.88      0.84       200
#      Brinjal       0.66      0.79      0.72       200
#     Broccoli       0.80      0.82      0.81       200
#      Cabbage       0.75      0.66      0.70       200
#     Capsicum       0.77      0.75      0.76       200
#       Carrot       0.89      0.70      0.78       200
#  Cauliflower       0.74      0.72      0.73       200
#     Cucumber       0.84      0.90      0.87       200
#       Papaya       0.78      0.81      0.79       200
#       Potato       0.91      0.69      0.78       200
#      Pumpkin       0.81      0.81      0.81       200
#       Radish       0.82      0.68      0.74       200
#       Tomato       0.66      0.75      0.70       200
#
#     accuracy                           0.78      3000
#    macro avg       0.78      0.78      0.78      3000
# weighted avg       0.78      0.78      0.78      3000

# %% [markdown]
# ## Trying GlobalAveragePooling2D instead of Flatten

# %% [markdown]
# ### Modelling
#
# Explanation
# - Global Pooling condenses all of the feature maps into a single one, pooling all of the relevant information into a single map that can be easily understood by a single dense classification layer instead of multiple layers.
# - I tried both GlobalAveragePooling2D and GlobalMaxPooling2D which both gave the same test accuracy.
#
# Why should i not use Flatten
# - When flattening, the network has to learn from oddly-shaped vectors in a very inefficient manner.
#
# Reference: https://stackabuse.com/dont-use-flatten-global-pooling-for-cnns-with-tensorflow-and-keras/

# %%
from keras.layers import GlobalMaxPooling2D

# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.5))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))  
model.add(Dropout(0.25))
model.add(GlobalMaxPooling2D())
model.add(Dense(64, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=15, batch_size=64, verbose=1)
# Out:
# Epoch 1/15
# 142/142 [==============================] - 5s 29ms/step - loss: 2.4604 - accuracy: 0.1756 - val_loss: 2.3722 - val_accuracy: 0.2260
# Epoch 2/15
# 142/142 [==============================] - 4s 27ms/step - loss: 1.7983 - accuracy: 0.4270 - val_loss: 1.7679 - val_accuracy: 0.4207
# Epoch 3/15
# 142/142 [==============================] - 4s 27ms/step - loss: 1.3326 - accuracy: 0.5737 - val_loss: 1.2169 - val_accuracy: 0.6300
# Epoch 4/15
# 142/142 [==============================] - 4s 28ms/step - loss: 1.0262 - accuracy: 0.6724 - val_loss: 1.0691 - val_accuracy: 0.6550
# Epoch 5/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.8594 - accuracy: 0.7303 - val_loss: 0.9502 - val_accuracy: 0.7040
# Epoch 6/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.7729 - accuracy: 0.7496 - val_loss: 0.7402 - val_accuracy: 0.7850
# Epoch 7/15
# 142/142 [==============================] - 4s 28ms/step - loss: 0.6365 - accuracy: 0.7977 - val_loss: 0.6643 - val_accuracy: 0.7937
# Epoch 8/15
# 142/142 [==============================] - 4s 28ms/step - loss: 0.5938 - accuracy: 0.8091 - val_loss: 0.6358 - val_accuracy: 0.8080
# Epoch 9/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.5092 - accuracy: 0.8367 - val_loss: 0.6806 - val_accuracy: 0.7743
# Epoch 10/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.5065 - accuracy: 0.8395 - val_loss: 0.6384 - val_accuracy: 0.8063
# Epoch 11/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.4370 - accuracy: 0.8581 - val_loss: 0.5689 - val_accuracy: 0.8267
# Epoch 12/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.4064 - accuracy: 0.8674 - val_loss: 0.5322 - val_accuracy: 0.8343
# Epoch 13/15
# 142/142 [==============================] - 4s 28ms/step - loss: 0.3581 - accuracy: 0.8838 - val_loss: 0.4761 - val_accuracy: 0.8523
# Epoch 14/15
# 142/142 [==============================] - 4s 27ms/step - loss: 0.3320 - accuracy: 0.8921 - val_loss: 0.4679 - val_accuracy: 0.8583
# Epoch 15/15
# 142/142 [==============================] - 4s 28ms/step - loss: 0.2821 - accuracy: 0.9076 - val_loss: 0.4989 - val_accuracy: 0.8560

# %% [markdown]
# ### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_127"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_387 (Conv2D)         (None, 128, 128, 128)     2176
#
#  max_pooling2d_165 (MaxPooli  (None, 42, 42, 128)      0
#  ng2D)
#
#  dropout_312 (Dropout)       (None, 42, 42, 128)       0
#
#  conv2d_388 (Conv2D)         (None, 39, 39, 128)       262272
#
#  max_pooling2d_166 (MaxPooli  (None, 13, 13, 128)      0
#  ng2D)
#
#  dropout_313 (Dropout)       (None, 13, 13, 128)       0
#
#  conv2d_389 (Conv2D)         (None, 10, 10, 128)       262272
#
#  max_pooling2d_167 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  dropout_314 (Dropout)       (None, 3, 3, 128)         0
#
#  global_max_pooling2d_4 (Glo  (None, 128)              0
#  balMaxPooling2D)
#
#  dense_316 (Dense)           (None, 64)                8256
#
#  dense_317 (Dense)           (None, 15)                975
#
# =================================================================
# Total params: 535,951
# Trainable params: 535,951
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4791 - accuracy: 0.8630
#
# Test accuracy: 86.30%

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.4988566040992737
# Validation Accuracy: 0.8560000061988831

# %% [markdown]
# #### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 0s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.94      0.85      0.90       200
# Bitter_Gourd       0.86      0.96      0.91       200
# Bottle_Gourd       0.90      0.95      0.93       200
#      Brinjal       0.73      0.93      0.82       200
#     Broccoli       0.93      0.96      0.95       200
#      Cabbage       0.90      0.86      0.88       200
#     Capsicum       0.95      0.80      0.87       200
#       Carrot       0.95      0.78      0.85       200
#  Cauliflower       0.89      0.91      0.90       200
#     Cucumber       0.84      0.96      0.90       200
#       Papaya       0.72      0.94      0.82       200
#       Potato       0.80      0.77      0.79       200
#      Pumpkin       0.81      0.98      0.89       200
#       Radish       0.98      0.53      0.68       200
#       Tomato       0.93      0.76      0.84       200
#
#     accuracy                           0.86      3000
#    macro avg       0.88      0.86      0.86      3000
# weighted avg       0.88      0.86      0.86      3000

# %% [markdown]
# # **Improving CNN Model**

# %% [markdown]
# ## RandomSearchCV + Stratified Kfold
#
# RandomSearchCV Explanation
# - RandomSearchCV requires fewer iterations than GridSearchCv as it samples a fixed number of parameter settings, hence its more efficient in the context of Deep Learning neural networks.
# - It provides a more diverse exploration of hyperparameter space which is beneficial for finding good hyperparameter configurations.
# - RandomizedSearchCV is preferred for efficiency, scalability, and exploration of the hyperparameter space.
#
# Stratified Kfold Explanation
# - StratifiedKflod ensures that each fold preserves the percentage of samples for each lables this making it a balanced class distribution.
# - It improves generalization to unseen data as they are trained on a more diverse set of samples.
# - StratifiedKFold is preferred for maintaining balanced class distribution, improving representativeness, and enhancing generalization of models, particularly in the context of imbalanced datasets.
#
# Reference:
# 1. https://www.linkedin.com/pulse/model-optimization-machine-learning-random-vs-neves-junior-phd-x459f/
# 2. https://www.kaggle.com/discussions/general/231173

# %% [markdown]
# ### Initialize

# %%
# Define hyperparameters
param_dist = {
    'conv_layers': [2, 3, 4],
    'filter_size': [32, 64, 128],
    'kernel_size': [(5, 5), (4, 4)],
    'stride_size': [(2, 2), (1, 1)], 
    'dense_layers': [1, 2, 3],
    'dropout_rate': [0.25, 0.3], 
    'epochs': [15],
    'batch_size': [32, 64]
}

# Define the CNN model
def create_cnn_model(conv_layers, filter_size, kernel_size, stride_size, dense_layers, dropout_rate):
    model = Sequential()

    # Input layer
    model.add(Conv2D(filter_size, kernel_size, input_shape=(131, 131, 1), strides=stride_size, activation='relu'))
    model.add(MaxPooling2D(2,2))
    
    # Hidden layers
    for _ in range(conv_layers):
        filter_size *= 2
        model.add(Conv2D(filter_size, kernel_size, strides=stride_size, activation='relu'))

    # Flatten
    model.add(Flatten())

    # Dense layer
    for _ in range(dense_layers):
        model.add(Dense(filter_size, activation='relu'))
        model.add(Dropout(dropout_rate))

    # Output layer
    model.add(Dense(15, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Initialize stratified k-fold cross-validator
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize the CNN model
model = KerasClassifier(build_fn=create_cnn_model)

# Initialize and fit the RandomizedSearchCV
randomCV = RandomizedSearchCV(estimator=model, param_distributions=param_dist, cv=stratified_kfold, verbose=2, n_iter=10, random_state=42)
randomCV_results = randomCV.fit(X_train, y_train_labels)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.3, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   1.6s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.3, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.3, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.3, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.3, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# Epoch 1/15
# 226/226 [==============================] - 14s 38ms/step - loss: 2.6120 - accuracy: 0.1907
# Epoch 2/15
# 226/226 [==============================] - 8s 34ms/step - loss: 1.8945 - accuracy: 0.4074
# Epoch 3/15
# 226/226 [==============================] - 8s 34ms/step - loss: 1.3044 - accuracy: 0.5946
# Epoch 4/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.8354 - accuracy: 0.7409
# Epoch 5/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.4975 - accuracy: 0.8439
# Epoch 6/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.3331 - accuracy: 0.8957
# Epoch 7/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.2266 - accuracy: 0.9284
# Epoch 8/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1714 - accuracy: 0.9414
# Epoch 9/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1763 - accuracy: 0.9478
# Epoch 10/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.1373 - accuracy: 0.9578
# Epoch 11/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.1163 - accuracy: 0.9648
# Epoch 12/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.0951 - accuracy: 0.9691
# Epoch 13/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0816 - accuracy: 0.9747
# Epoch 14/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.0919 - accuracy: 0.9727
# Epoch 15/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0789 - accuracy: 0.9760
# 57/57 [==============================] - 1s 11ms/step - loss: 2.5718 - accuracy: 0.6429
# [CV] END batch_size=32, conv_layers=3, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time= 2.1min
# Epoch 1/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.8872 - accuracy: 0.0906
# Epoch 2/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6428 - accuracy: 0.1026
# Epoch 3/15
# 226/226 [==============================] - 8s 36ms/step - loss: 2.6371 - accuracy: 0.1044
# Epoch 4/15
# 226/226 [==============================] - 8s 36ms/step - loss: 2.6377 - accuracy: 0.1037
# Epoch 5/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6370 - accuracy: 0.1054
# Epoch 6/15
# 226/226 [==============================] - 8s 34ms/step - loss: 2.6365 - accuracy: 0.1050
# Epoch 7/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6374 - accuracy: 0.1032
# Epoch 8/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6375 - accuracy: 0.1045
# Epoch 9/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6366 - accuracy: 0.1058
# Epoch 10/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6360 - accuracy: 0.1065
# Epoch 11/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6364 - accuracy: 0.1045
# Epoch 12/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6355 - accuracy: 0.1041
# Epoch 13/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6365 - accuracy: 0.1045
# Epoch 14/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6363 - accuracy: 0.1058
# Epoch 15/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6371 - accuracy: 0.1058
# 57/57 [==============================] - 1s 9ms/step - loss: 2.6344 - accuracy: 0.1058
# [CV] END batch_size=32, conv_layers=3, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time= 2.0min
# Epoch 1/15
# 226/226 [==============================] - 9s 37ms/step - loss: 2.6678 - accuracy: 0.2101
# Epoch 2/15
# 226/226 [==============================] - 8s 36ms/step - loss: 2.0203 - accuracy: 0.3811
# Epoch 3/15
# 226/226 [==============================] - 8s 35ms/step - loss: 1.5288 - accuracy: 0.5378
# Epoch 4/15
# 226/226 [==============================] - 8s 35ms/step - loss: 1.0775 - accuracy: 0.6702
# Epoch 5/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.7117 - accuracy: 0.7721
# Epoch 6/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.4957 - accuracy: 0.8433
# Epoch 7/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.3568 - accuracy: 0.8899
# Epoch 8/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.2684 - accuracy: 0.9186
# Epoch 9/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.2051 - accuracy: 0.9345
# Epoch 10/15
# 226/226 [==============================] - 8s 36ms/step - loss: 0.1803 - accuracy: 0.9466
# Epoch 11/15
# 226/226 [==============================] - 8s 36ms/step - loss: 0.1566 - accuracy: 0.9503
# Epoch 12/15
# 226/226 [==============================] - 8s 37ms/step - loss: 0.1179 - accuracy: 0.9650
# Epoch 13/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1122 - accuracy: 0.9659
# Epoch 14/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0982 - accuracy: 0.9694
# Epoch 15/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0906 - accuracy: 0.9726
# 57/57 [==============================] - 1s 9ms/step - loss: 2.9500 - accuracy: 0.5991
# [CV] END batch_size=32, conv_layers=3, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time= 2.0min
# Epoch 1/15
# 226/226 [==============================] - 9s 39ms/step - loss: 2.6064 - accuracy: 0.2124
# Epoch 2/15
# 226/226 [==============================] - 8s 35ms/step - loss: 1.6911 - accuracy: 0.4692
# Epoch 3/15
# 226/226 [==============================] - 8s 35ms/step - loss: 1.1705 - accuracy: 0.6298
# Epoch 4/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.7413 - accuracy: 0.7702
# Epoch 5/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.4114 - accuracy: 0.8690
# Epoch 6/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.2836 - accuracy: 0.9085
# Epoch 7/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1842 - accuracy: 0.9392
# Epoch 8/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1275 - accuracy: 0.9605
# Epoch 9/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1024 - accuracy: 0.9675
# Epoch 10/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.0980 - accuracy: 0.9705
# Epoch 11/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0931 - accuracy: 0.9716
# Epoch 12/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0676 - accuracy: 0.9770
# Epoch 13/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0646 - accuracy: 0.9814
# Epoch 14/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0830 - accuracy: 0.9733
# Epoch 15/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0558 - accuracy: 0.9838
# 57/57 [==============================] - 1s 11ms/step - loss: 1.7787 - accuracy: 0.6903
# [CV] END batch_size=32, conv_layers=3, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time= 2.0min
# Epoch 1/15
# 226/226 [==============================] - 8s 35ms/step - loss: 2.6099 - accuracy: 0.1832
# Epoch 2/15
# 226/226 [==============================] - 8s 35ms/step - loss: 1.7983 - accuracy: 0.4274
# Epoch 3/15
# 226/226 [==============================] - 8s 35ms/step - loss: 1.3130 - accuracy: 0.5866
# Epoch 4/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.9386 - accuracy: 0.7010
# Epoch 5/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.6189 - accuracy: 0.8009
# Epoch 6/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.4340 - accuracy: 0.8577
# Epoch 7/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.3136 - accuracy: 0.9003
# Epoch 8/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.2050 - accuracy: 0.9348
# Epoch 9/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1915 - accuracy: 0.9416
# Epoch 10/15
# 226/226 [==============================] - 8s 37ms/step - loss: 0.1489 - accuracy: 0.9568
# Epoch 11/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1058 - accuracy: 0.9697
# Epoch 12/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0898 - accuracy: 0.9736
# Epoch 13/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.1144 - accuracy: 0.9654
# Epoch 14/15
# 226/226 [==============================] - 8s 35ms/step - loss: 0.0974 - accuracy: 0.9716
# Epoch 15/15
# 226/226 [==============================] - 8s 34ms/step - loss: 0.0716 - accuracy: 0.9769
# 57/57 [==============================] - 1s 9ms/step - loss: 2.1653 - accuracy: 0.6654
# [CV] END batch_size=32, conv_layers=3, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time= 2.0min
# [CV] END batch_size=32, conv_layers=4, dense_layers=2, dropout_rate=0.3, epochs=15, filter_size=32, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=2, dropout_rate=0.3, epochs=15, filter_size=32, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=2, dropout_rate=0.3, epochs=15, filter_size=32, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=2, dropout_rate=0.3, epochs=15, filter_size=32, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=2, dropout_rate=0.3, epochs=15, filter_size=32, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# Epoch 1/15
# 226/226 [==============================] - 2s 7ms/step - loss: 2.4986 - accuracy: 0.1351
# Epoch 2/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.9015 - accuracy: 0.3711
# Epoch 3/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.3955 - accuracy: 0.5528
# Epoch 4/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.0729 - accuracy: 0.6476
# Epoch 5/15
# 226/226 [==============================] - 1s 7ms/step - loss: 0.7927 - accuracy: 0.7427
# Epoch 6/15
# 226/226 [==============================] - 1s 7ms/step - loss: 0.6189 - accuracy: 0.8010
# Epoch 7/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.4668 - accuracy: 0.8444
# Epoch 8/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.3505 - accuracy: 0.8866
# Epoch 9/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.3199 - accuracy: 0.8928
# Epoch 10/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2387 - accuracy: 0.9234
# Epoch 11/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1860 - accuracy: 0.9410
# Epoch 12/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1844 - accuracy: 0.9387
# Epoch 13/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1482 - accuracy: 0.9515
# Epoch 14/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1420 - accuracy: 0.9554
# Epoch 15/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1111 - accuracy: 0.9632
# 57/57 [==============================] - 0s 4ms/step - loss: 0.7730 - accuracy: 0.8350
# [CV] END batch_size=32, conv_layers=2, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=  24.6s
# Epoch 1/15
# 226/226 [==============================] - 2s 7ms/step - loss: 2.4559 - accuracy: 0.1581
# Epoch 2/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.9183 - accuracy: 0.3636
# Epoch 3/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.4479 - accuracy: 0.5222
# Epoch 4/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.1248 - accuracy: 0.6357
# Epoch 5/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.8373 - accuracy: 0.7220
# Epoch 6/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.6702 - accuracy: 0.7840
# Epoch 7/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.5046 - accuracy: 0.8361
# Epoch 8/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.4106 - accuracy: 0.8683
# Epoch 9/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.3032 - accuracy: 0.9049
# Epoch 10/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2568 - accuracy: 0.9171
# Epoch 11/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2425 - accuracy: 0.9216
# Epoch 12/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2092 - accuracy: 0.9312
# Epoch 13/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1697 - accuracy: 0.9442
# Epoch 14/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1322 - accuracy: 0.9543
# Epoch 15/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1650 - accuracy: 0.9484
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5252 - accuracy: 0.8671
# [CV] END batch_size=32, conv_layers=2, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=  25.5s
# Epoch 1/15
# 226/226 [==============================] - 2s 7ms/step - loss: 2.4434 - accuracy: 0.1570
# Epoch 2/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.9464 - accuracy: 0.3582
# Epoch 3/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.4882 - accuracy: 0.5107
# Epoch 4/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.2079 - accuracy: 0.6001
# Epoch 5/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.8962 - accuracy: 0.7081
# Epoch 6/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.7056 - accuracy: 0.7660
# Epoch 7/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.5414 - accuracy: 0.8243
# Epoch 8/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.4185 - accuracy: 0.8603
# Epoch 9/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.3233 - accuracy: 0.8953
# Epoch 10/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2737 - accuracy: 0.9078
# Epoch 11/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2241 - accuracy: 0.9248
# Epoch 12/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2110 - accuracy: 0.9294
# Epoch 13/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1807 - accuracy: 0.9394
# Epoch 14/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1810 - accuracy: 0.9384
# Epoch 15/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1619 - accuracy: 0.9466
# 57/57 [==============================] - 0s 4ms/step - loss: 0.7439 - accuracy: 0.8278
# [CV] END batch_size=32, conv_layers=2, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=  24.8s
# Epoch 1/15
# 226/226 [==============================] - 2s 7ms/step - loss: 2.4040 - accuracy: 0.1843
# Epoch 2/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.7476 - accuracy: 0.4290
# Epoch 3/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.3467 - accuracy: 0.5549
# Epoch 4/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.0093 - accuracy: 0.6693
# Epoch 5/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.7643 - accuracy: 0.7516
# Epoch 6/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.5373 - accuracy: 0.8289
# Epoch 7/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.4312 - accuracy: 0.8581
# Epoch 8/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.3404 - accuracy: 0.8909
# Epoch 9/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2548 - accuracy: 0.9186
# Epoch 10/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2094 - accuracy: 0.9341
# Epoch 11/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2099 - accuracy: 0.9275
# Epoch 12/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1723 - accuracy: 0.9432
# Epoch 13/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1678 - accuracy: 0.9428
# Epoch 14/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1413 - accuracy: 0.9509
# Epoch 15/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1462 - accuracy: 0.9568
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6148 - accuracy: 0.8432
# [CV] END batch_size=32, conv_layers=2, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=  25.4s
# Epoch 1/15
# 226/226 [==============================] - 2s 7ms/step - loss: 2.4917 - accuracy: 0.1339
# Epoch 2/15
# 226/226 [==============================] - 2s 7ms/step - loss: 2.0801 - accuracy: 0.3011
# Epoch 3/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.6063 - accuracy: 0.4751
# Epoch 4/15
# 226/226 [==============================] - 2s 7ms/step - loss: 1.2769 - accuracy: 0.5867
# Epoch 5/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.9660 - accuracy: 0.6881
# Epoch 6/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.7374 - accuracy: 0.7630
# Epoch 7/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.5869 - accuracy: 0.8117
# Epoch 8/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.4636 - accuracy: 0.8485
# Epoch 9/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.3599 - accuracy: 0.8845
# Epoch 10/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.3317 - accuracy: 0.8938
# Epoch 11/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2570 - accuracy: 0.9144
# Epoch 12/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.2121 - accuracy: 0.9316
# Epoch 13/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1885 - accuracy: 0.9367
# Epoch 14/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1647 - accuracy: 0.9477
# Epoch 15/15
# 226/226 [==============================] - 2s 7ms/step - loss: 0.1656 - accuracy: 0.9456
# 57/57 [==============================] - 0s 4ms/step - loss: 0.8296 - accuracy: 0.8116
# [CV] END batch_size=32, conv_layers=2, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=  25.2s
# [CV] END batch_size=64, conv_layers=4, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.2s
# [CV] END batch_size=64, conv_layers=4, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=2, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# Epoch 1/15
# 113/113 [==============================] - 41s 253ms/step - loss: 2.9677 - accuracy: 0.1117
# Epoch 2/15
# 113/113 [==============================] - 19s 169ms/step - loss: 2.3154 - accuracy: 0.2181
# Epoch 3/15
# 113/113 [==============================] - 19s 168ms/step - loss: 1.9850 - accuracy: 0.3442
# Epoch 4/15
# 113/113 [==============================] - 19s 168ms/step - loss: 1.5676 - accuracy: 0.5028
# Epoch 5/15
# 113/113 [==============================] - 19s 167ms/step - loss: 1.1963 - accuracy: 0.6248
# Epoch 6/15
# 113/113 [==============================] - 19s 167ms/step - loss: 0.9283 - accuracy: 0.7026
# Epoch 7/15
# 113/113 [==============================] - 19s 168ms/step - loss: 0.6694 - accuracy: 0.7807
# Epoch 8/15
# 113/113 [==============================] - 19s 168ms/step - loss: 0.5160 - accuracy: 0.8351
# Epoch 9/15
# 113/113 [==============================] - 19s 168ms/step - loss: 0.3911 - accuracy: 0.8780
# Epoch 10/15
# 113/113 [==============================] - 19s 166ms/step - loss: 0.2994 - accuracy: 0.9050
# Epoch 11/15
# 113/113 [==============================] - 19s 167ms/step - loss: 0.2201 - accuracy: 0.9298
# Epoch 12/15
# 113/113 [==============================] - 19s 165ms/step - loss: 0.1824 - accuracy: 0.9443
# Epoch 13/15
# 113/113 [==============================] - 19s 165ms/step - loss: 0.1673 - accuracy: 0.9486
# Epoch 14/15
# 113/113 [==============================] - 19s 167ms/step - loss: 0.1465 - accuracy: 0.9574
# Epoch 15/15
# 113/113 [==============================] - 19s 166ms/step - loss: 0.1689 - accuracy: 0.9481
# 29/29 [==============================] - 2s 49ms/step - loss: 1.4140 - accuracy: 0.6849
# [CV] END batch_size=64, conv_layers=2, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(1, 1); total time= 5.1min
# [CV] END batch_size=64, conv_layers=2, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=64, conv_layers=2, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=64, conv_layers=2, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=64, conv_layers=2, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.2s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=64, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.2s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=128, kernel_size=(4, 4), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=32, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=32, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=32, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=32, conv_layers=4, dense_layers=3, dropout_rate=0.25, epochs=15, filter_size=32, kernel_size=(4, 4), stride_size=(1, 1); total time=  10.3s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# [CV] END batch_size=32, conv_layers=4, dense_layers=1, dropout_rate=0.25, epochs=15, filter_size=64, kernel_size=(5, 5), stride_size=(2, 2); total time=   0.1s
# Epoch 1/15
# 283/283 [==============================] - 2s 7ms/step - loss: 2.3944 - accuracy: 0.1825
# Epoch 2/15
# 283/283 [==============================] - 2s 7ms/step - loss: 1.7252 - accuracy: 0.4389
# Epoch 3/15
# 283/283 [==============================] - 2s 7ms/step - loss: 1.2183 - accuracy: 0.6129
# Epoch 4/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.8711 - accuracy: 0.7177
# Epoch 5/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.6707 - accuracy: 0.7897
# Epoch 6/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.4800 - accuracy: 0.8449
# Epoch 7/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.3639 - accuracy: 0.8780
# Epoch 8/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.2714 - accuracy: 0.9128
# Epoch 9/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.2566 - accuracy: 0.9167
# Epoch 10/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.2173 - accuracy: 0.9299
# Epoch 11/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.1846 - accuracy: 0.9412
# Epoch 12/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.1507 - accuracy: 0.9502
# Epoch 13/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.1481 - accuracy: 0.9529
# Epoch 14/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.1334 - accuracy: 0.9531
# Epoch 15/15
# 283/283 [==============================] - 2s 7ms/step - loss: 0.1322 - accuracy: 0.9591

# %% [markdown]
# ### Evaluation on test

# %%
# Print the best parameters and corresponding accuracy
print("Best Parameters:", randomCV.best_params_)
print("Best Accuracy:", randomCV.best_score_)

# Get the best model
best_model = randomCV_results.best_estimator_.model

# Evaluate the best model on the test set
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
# Out:
# Best Parameters: {'stride_size': (2, 2), 'kernel_size': (4, 4), 'filter_size': 64, 'epochs': 15, 'dropout_rate': 0.25, 'dense_layers': 2, 'conv_layers': 2, 'batch_size': 32}
# Best Accuracy: 0.836949598789215
# 94/94 [==============================] - 0s 4ms/step - loss: 0.6093 - accuracy: 0.8473
# Test Accuracy: 84.73%

# %% [markdown]
# ### Use best parameters and create the model

# %%
# Best params
best_params = randomCV_results.best_params_

# Create model using similar function as the randomCV
def create_best_cnn_model():
    model = Sequential()

    # Input layer
    model.add(Conv2D(best_params['filter_size'], best_params['kernel_size'], input_shape=(131, 131, 1), strides=best_params['stride_size'], activation='relu'))
    model.add(MaxPooling2D(3,3))
    
    # Hidden layers
    for _ in range(best_params['conv_layers']):
        best_params['filter_size'] *= 2
        model.add(Conv2D(best_params['filter_size'], best_params['kernel_size'], strides=best_params['stride_size'], activation='relu'))

    # Flatten
    model.add(Flatten())

    # Dense layer
    for _ in range(best_params['dense_layers']):
        model.add(Dense(best_params['filter_size'], activation='relu'))
        model.add(Dropout(best_params['dropout_rate']))

    # Output layer
    model.add(Dense(15, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Call the create best CNN model function
best_model = create_best_cnn_model()

history = best_model.fit(X_train, y_train, 
                         batch_size=best_params['batch_size'], 
                         epochs=best_params['epochs'], 
                         validation_data=(X_validation, y_validation))

# View the layer summary
best_model.summary()

# Final evaluation of the model 
test_loss, test_acc = best_model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Epoch 1/15
# 283/283 [==============================] - 3s 9ms/step - loss: 2.3761 - accuracy: 0.1859 - val_loss: 2.0771 - val_accuracy: 0.3143
# Epoch 2/15
# 283/283 [==============================] - 2s 7ms/step - loss: 1.7617 - accuracy: 0.4258 - val_loss: 1.5248 - val_accuracy: 0.4690
# Epoch 3/15
# 283/283 [==============================] - 2s 8ms/step - loss: 1.3609 - accuracy: 0.5537 - val_loss: 1.5271 - val_accuracy: 0.5013
# Epoch 4/15
# 283/283 [==============================] - 2s 8ms/step - loss: 1.1071 - accuracy: 0.6402 - val_loss: 1.0112 - val_accuracy: 0.6817
# Epoch 5/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.8388 - accuracy: 0.7321 - val_loss: 0.8810 - val_accuracy: 0.7127
# Epoch 6/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.7117 - accuracy: 0.7714 - val_loss: 1.1216 - val_accuracy: 0.6537
# Epoch 7/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.5709 - accuracy: 0.8181 - val_loss: 0.6126 - val_accuracy: 0.8057
# Epoch 8/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.4706 - accuracy: 0.8499 - val_loss: 0.7721 - val_accuracy: 0.7597
# Epoch 9/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.3881 - accuracy: 0.8725 - val_loss: 0.6601 - val_accuracy: 0.7990
# Epoch 10/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.3404 - accuracy: 0.8893 - val_loss: 0.5804 - val_accuracy: 0.8273
# Epoch 11/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.2898 - accuracy: 0.9056 - val_loss: 0.6716 - val_accuracy: 0.7970
# Epoch 12/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.2907 - accuracy: 0.9060 - val_loss: 0.5733 - val_accuracy: 0.8460
# Epoch 13/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.2038 - accuracy: 0.9352 - val_loss: 0.6439 - val_accuracy: 0.8170
# Epoch 14/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.2390 - accuracy: 0.9200 - val_loss: 0.5723 - val_accuracy: 0.8573
# Epoch 15/15
# 283/283 [==============================] - 2s 8ms/step - loss: 0.1602 - accuracy: 0.9444 - val_loss: 0.5587 - val_accuracy: 0.8510
# Model: "sequential_51"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_228 (Conv2D)         (None, 64, 64, 64)        1088
#
#  max_pooling2d_51 (MaxPoolin  (None, 21, 21, 64)       0
#  g2D)
#
#  conv2d_229 (Conv2D)         (None, 9, 9, 128)         131200
#
#  conv2d_230 (Conv2D)         (None, 3, 3, 256)         524544
#
#  flatten_21 (Flatten)        (None, 2304)              0
#
#  dense_41 (Dense)            (None, 256)               590080
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_42 (Dense)            (None, 256)               65792
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_43 (Dense)            (None, 15)                3855
#
# =================================================================
# Total params: 1,316,559
# Trainable params: 1,316,559
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 0s 4ms/step - loss: 0.5349 - accuracy: 0.8663
#
# Test accuracy: 86.63%

# %% [markdown]
# ## Finding the best Activation Function and Optimizer
#
# Activation Function Explanation
# - ReLU (Rectified Linear Unit) helps the  model learn complex patterns by allowing it to model non-linear relationships between the features.
# - Tanh (Hyperbolic Tangent) is used in binary classification tasks and provides outputs in a symmetrical range around zero.
# - Leaky ReLU is a variant of ReLU and it helps to increase the range of the ReLU function.
#
# Optimizer Explanation
# - Adam (Adaptive Moment Estimation) adapts the learning rate during training and keeps an exponentially decaying average of past gradients.
# - RMSprop (Root Mean Square Propagation) divides the learning rate by the root of this moving average, which helps to normalize the updates and improve convergence.
# - SGD (Stochastic Gradient Descent) updates the parameters of the model in the direction of the negative gradient of the loss function with respect to the parameters.
#
# References
# 1. https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6
# 2. https://www.analyticsvidhya.com/blog/2021/10/a-comprehensive-guide-on-deep-learning-optimizers/

# %%
# list of activation functions to test
activation_functions = ['relu', 'tanh', LeakyReLU(alpha=0.1)]
optimizers = ['adam', 'rmsprop', 'sgd']

# Store the results
results = {}

for activation_func in activation_functions:
    for optimizer_name in optimizers:
        # Create model 
        model = Sequential() 
        model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation=activation_func))
        model.add(MaxPooling2D(pool_size=(3, 3))) 
        model.add(Dropout(0.5))
        model.add(Conv2D(128, (4, 4), activation=activation_func))
        model.add(MaxPooling2D(pool_size=(3, 3))) 
        model.add(Dropout(0.25))
        model.add(Conv2D(128, (4, 4), activation=activation_func))
        model.add(MaxPooling2D(pool_size=(3, 3)))  
        model.add(Dropout(0.25))
        model.add(Flatten())
        model.add(Dense(64, activation=activation_func)) 
        model.add(Dense(num_classes, activation='softmax')) 
    
        # Compile the model
        model.compile(loss='categorical_crossentropy', optimizer=optimizer_name, metrics=['accuracy'])
    
        # Train the model
        history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                            epochs=15, batch_size=64, verbose=1)

        # Evaluate the model
        test_loss, test_acc = model.evaluate(X_test, y_test)

        # Store the results
        results[(activation_func, optimizer_name)] = test_acc

# Sort the results dictionary based on test accuracy
sorted_results = sorted(results.items(), key=lambda x: x[1], reverse=True)

# %%
# Print the best accuracy
best_activation_func, best_optimizer, best_accuracy = sorted_results[0][0][0], sorted_results[0][0][1], sorted_results[0][1]
print(f"Best Accuracy: {best_accuracy*100:.2f}%\nActivation Function: {best_activation_func}\nOptimizer: {best_optimizer}")
# Out:
# Best Accuracy: 93.53%
# Activation Function: <keras.layers.activation.leaky_relu.LeakyReLU object at 0x000002211FBB8C70>
# Optimizer: adam

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# ### Convert grayscale to rgb

# %%
# Images needs to have 3 channels
def grayscale_to_rgb(grayscale_images):

    # 
    num_images, height, width = grayscale_images.shape
    
    # Convert to 3D array by replicating grayscale across RGB
    rgb_images = np.repeat(grayscale_images[..., np.newaxis], 3, axis=-1)
    
    return rgb_images

# Convert the datasets
X_train_rgb = grayscale_to_rgb(X_train)
X_validation_rgb = grayscale_to_rgb(X_validation)
X_test_rgb = grayscale_to_rgb(X_test)

# %% [markdown]
# ### VGG16
#
# Explanation
# - VGG16 is a pre=trained deep learning model that has been used for image classification
# - It is able to extract high-level and complex features from the input images which allows it to capture more complex patterns and relationships between the input features therefore leading to improved performance.
# - It is effective due to its simplicity, availability, transfer learning capabilities, compatibility, and competitive performance.
#
# Reference: https://medium.com/@jaeheonk817/concept-vgg16-power-of-transfer-learning-on-image-classification-a9c0b3ee27f8

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D

# Find number of labels
num_classes = len(np.unique(y_train_labels))

# Load pre-trained VGG16 model (excluding top layers) with weights trained on ImageNet
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(131, 131, 3))

# Freeze convolutional layers
base_model.trainable = False

# Create model
model = Sequential() 
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu')) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=4, min_delta=0.001)

# Fine-tune the model on your dataset
history = model.fit(X_train_rgb, y_train, validation_data=(X_validation_rgb, y_validation),
          epochs=15, batch_size=64, verbose=1, callbacks=[early_stopping])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Epoch 1/15
# 142/142 [==============================] - 9s 53ms/step - loss: 1.4877 - accuracy: 0.6004 - val_loss: 0.9924 - val_accuracy: 0.7213
# Epoch 2/15
# 142/142 [==============================] - 6s 39ms/step - loss: 0.6943 - accuracy: 0.8211 - val_loss: 0.6529 - val_accuracy: 0.8220
# Epoch 3/15
# 142/142 [==============================] - 6s 39ms/step - loss: 0.4838 - accuracy: 0.8747 - val_loss: 0.4881 - val_accuracy: 0.8670
# Epoch 4/15
# 142/142 [==============================] - 6s 39ms/step - loss: 0.3690 - accuracy: 0.9072 - val_loss: 0.4218 - val_accuracy: 0.8803
# Epoch 5/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.3011 - accuracy: 0.9263 - val_loss: 0.3400 - val_accuracy: 0.9107
# Epoch 6/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.2517 - accuracy: 0.9376 - val_loss: 0.2870 - val_accuracy: 0.9273
# Epoch 7/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.2140 - accuracy: 0.9504 - val_loss: 0.2564 - val_accuracy: 0.9347
# Epoch 8/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.1860 - accuracy: 0.9564 - val_loss: 0.2271 - val_accuracy: 0.9423
# Epoch 9/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.1625 - accuracy: 0.9637 - val_loss: 0.2355 - val_accuracy: 0.9337
# Epoch 10/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.1494 - accuracy: 0.9659 - val_loss: 0.2203 - val_accuracy: 0.9400
# Epoch 11/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.1261 - accuracy: 0.9723 - val_loss: 0.1879 - val_accuracy: 0.9517
# Epoch 12/15
# 142/142 [==============================] - 6s 41ms/step - loss: 0.1137 - accuracy: 0.9751 - val_loss: 0.1741 - val_accuracy: 0.9563
# Epoch 13/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.1074 - accuracy: 0.9773 - val_loss: 0.1661 - val_accuracy: 0.9580
# Epoch 14/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.0960 - accuracy: 0.9808 - val_loss: 0.1638 - val_accuracy: 0.9537
# Epoch 15/15
# 142/142 [==============================] - 6s 40ms/step - loss: 0.0942 - accuracy: 0.9800 - val_loss: 0.1581 - val_accuracy: 0.9567

# %% [markdown]
# #### Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test_rgb, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_69"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_202 (Dense)           (None, 256)               131328
#
#  dense_203 (Dense)           (None, 15)                3855
#
# =================================================================
# Total params: 14,849,871
# Trainable params: 135,183
# Non-trainable params: 14,714,688
# _________________________________________________________________
# 94/94 [==============================] - 3s 23ms/step - loss: 0.1507 - accuracy: 0.9580
#
# Test accuracy: 95.80%

# %% [markdown]
# ### MobileNet
#
# Explanation
# - Mobilenets are designed to be efficient, meaning they can run on limited computational resources.
# - It is also typically much faster than traditional convolutional neural networks.
# - They are smaller sizes and only need a small memory footprint therefore they are easy to deploy and use.
#
# Reference: https://medium.com/@nocodingai/mobilenet-fc34af9f58a5

# %%
# from tensorflow.keras.applications import MobileNet
# from tensorflow.keras.layers import GlobalAveragePooling2D

# # Find number of labels
# num_classes = len(np.unique(y_train_labels))

# # Load pre-trained MobileNet model (excluding top layers) with weights trained on ImageNet
# base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(131, 131, 3)) 

# # Freeze convolutional layers
# base_model.trainable = False

# # Create model
# model = Sequential() 
# model.add(base_model)
# model.add(GlobalAveragePooling2D())
# model.add(Dense(256, activation='relu')) 
# model.add(Dense(num_classes, activation='softmax')) 

# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # Define EarlyStopping callback
# early_stopping = EarlyStopping(monitor='val_loss', patience=4, min_delta=0.001)

# # Fine-tune the model on your dataset
# history = model.fit(X_train_rgb, y_train, validation_data=(X_validation_rgb, y_validation),
#           epochs=15, batch_size=64, verbose=1, callbacks=[early_stopping])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 2s 0us/step
# Epoch 1/15
# 142/142 [==============================] - 5s 23ms/step - loss: 0.2851 - accuracy: 0.9136 - val_loss: 0.0687 - val_accuracy: 0.9793
# Epoch 2/15
# 142/142 [==============================] - 3s 18ms/step - loss: 0.0277 - accuracy: 0.9937 - val_loss: 0.0429 - val_accuracy: 0.9860
# Epoch 3/15
# 142/142 [==============================] - 3s 18ms/step - loss: 0.0064 - accuracy: 0.9996 - val_loss: 0.0362 - val_accuracy: 0.9897
# Epoch 4/15
# 142/142 [==============================] - 3s 18ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9900
# Epoch 5/15
# 142/142 [==============================] - 3s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9897
# Epoch 6/15
# 142/142 [==============================] - 3s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9903
# Epoch 7/15
# 142/142 [==============================] - 3s 18ms/step - loss: 8.0258e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9903
# Epoch 8/15
# 142/142 [==============================] - 3s 18ms/step - loss: 6.4366e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9913
# Epoch 9/15
# 142/142 [==============================] - 3s 18ms/step - loss: 5.2542e-04 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9917
# Epoch 10/15
# 142/142 [==============================] - 3s 18ms/step - loss: 4.3357e-04 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9907
# Epoch 11/15
# 142/142 [==============================] - 3s 18ms/step - loss: 3.6580e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9907

# %% [markdown]
# #### Evaluation

# %%
# # View the layer summary
# model.summary()

# # Final evaluation of the model 
# test_loss, test_acc = model.evaluate(X_test_rgb, y_test)
# print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_70"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 4, 4, 1024)       3228864
#  nal)
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_204 (Dense)           (None, 256)               262400
#
#  dense_205 (Dense)           (None, 15)                3855
#
# =================================================================
# Total params: 3,495,119
# Trainable params: 266,255
# Non-trainable params: 3,228,864
# _________________________________________________________________
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0292 - accuracy: 0.9897
#
# Test accuracy: 98.97%

# %% [markdown]
# # **Final Model**

# %% [markdown]
# ## Modelling
#
# - From the CNN model's I found out that the best CNN model is using Convo2D, MaxPooling2D, Dropout
# - Using RandomSearchCV and Stratified Kfold, I found the best parameters
# - Using a loop function, I found the best Activation Function ('Leaky ReLU') and Optimizer ('Adam')

# %%
# Get the number of unique labels
num_classes = len(np.unique(y_train_labels))

# Create model 
model = Sequential() 
model.add(Conv2D(128, (4, 4), input_shape=(131, 131, 1), activation=LeakyReLU(alpha=0.1)))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), activation=LeakyReLU(alpha=0.1)))
model.add(MaxPooling2D(pool_size=(3, 3))) 
model.add(Dropout(0.25))
model.add(Conv2D(128, (4, 4), activation=LeakyReLU(alpha=0.1)))
model.add(MaxPooling2D(pool_size=(3, 3)))  
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation=LeakyReLU(alpha=0.1))) 
model.add(Dropout(0.25))
model.add(Dense(64, activation=LeakyReLU(alpha=0.1))) 
model.add(Dense(num_classes, activation='softmax')) 

# Compile model 
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])  

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=4, min_delta=0.001)

# Define ModelCheckpoint callback
model_checkpoint = ModelCheckpoint(filepath='best_model_131.h5', monitor='val_accuracy', save_best_only=True)

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
          epochs=30, batch_size=64, verbose=1, callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/30
# 142/142 [==============================] - 6s 36ms/step - loss: 2.4178 - accuracy: 0.1606 - val_loss: 2.3056 - val_accuracy: 0.2463
# Epoch 2/30
# 142/142 [==============================] - 5s 34ms/step - loss: 1.8877 - accuracy: 0.3721 - val_loss: 1.5022 - val_accuracy: 0.5057
# Epoch 3/30
# 142/142 [==============================] - 5s 34ms/step - loss: 1.2814 - accuracy: 0.5825 - val_loss: 1.0579 - val_accuracy: 0.6463
# Epoch 4/30
# 142/142 [==============================] - 5s 33ms/step - loss: 0.9638 - accuracy: 0.6895 - val_loss: 1.0442 - val_accuracy: 0.6543
# Epoch 5/30
# 142/142 [==============================] - 5s 34ms/step - loss: 0.7349 - accuracy: 0.7607 - val_loss: 0.8077 - val_accuracy: 0.7267
# Epoch 6/30
# 142/142 [==============================] - 5s 34ms/step - loss: 0.6767 - accuracy: 0.7815 - val_loss: 0.7558 - val_accuracy: 0.7483
# Epoch 7/30
# 142/142 [==============================] - 5s 34ms/step - loss: 0.5042 - accuracy: 0.8353 - val_loss: 0.5864 - val_accuracy: 0.8120
# Epoch 8/30
# 142/142 [==============================] - 5s 33ms/step - loss: 0.4485 - accuracy: 0.8547 - val_loss: 0.5781 - val_accuracy: 0.8073
# Epoch 9/30
# 142/142 [==============================] - 5s 34ms/step - loss: 0.3471 - accuracy: 0.8877 - val_loss: 0.3345 - val_accuracy: 0.8997
# Epoch 10/30
# 142/142 [==============================] - 5s 33ms/step - loss: 0.3287 - accuracy: 0.8938 - val_loss: 0.3336 - val_accuracy: 0.8943
# Epoch 11/30
# 142/142 [==============================] - 5s 33ms/step - loss: 0.3157 - accuracy: 0.8972 - val_loss: 0.3569 - val_accuracy: 0.8927
# Epoch 12/30
# 142/142 [==============================] - 5s 34ms/step - loss: 0.2981 - accuracy: 0.9013 - val_loss: 0.2634 - val_accuracy: 0.9160
# Epoch 13/30
# 142/142 [==============================] - 5s 35ms/step - loss: 0.2042 - accuracy: 0.9319 - val_loss: 0.2878 - val_accuracy: 0.9180
# Epoch 14/30
# 142/142 [==============================] - 5s 35ms/step - loss: 0.2165 - accuracy: 0.9253 - val_loss: 0.2766 - val_accuracy: 0.9190
# Epoch 15/30
# 142/142 [==============================] - 5s 35ms/step - loss: 0.1664 - accuracy: 0.9433 - val_loss: 0.3455 - val_accuracy: 0.9077
# Epoch 16/30
# 142/142 [==============================] - 5s 34ms/step - loss: 0.2095 - accuracy: 0.9314 - val_loss: 0.2699 - val_accuracy: 0.9223

# %% [markdown]
# ## Evaluation

# %%
# View the layer summary
model.summary()

# Final evaluation of the model 
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', f'{test_acc*100:.2f}%')
# Out:
# Model: "sequential_58"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_249 (Conv2D)         (None, 128, 128, 128)     2176
#
#  max_pooling2d_70 (MaxPoolin  (None, 42, 42, 128)      0
#  g2D)
#
#  dropout_42 (Dropout)        (None, 42, 42, 128)       0
#
#  conv2d_250 (Conv2D)         (None, 39, 39, 128)       262272
#
#  max_pooling2d_71 (MaxPoolin  (None, 13, 13, 128)      0
#  g2D)
#
#  dropout_43 (Dropout)        (None, 13, 13, 128)       0
#
#  conv2d_251 (Conv2D)         (None, 10, 10, 128)       262272
#
#  max_pooling2d_72 (MaxPoolin  (None, 3, 3, 128)        0
#  g2D)
#
#  dropout_44 (Dropout)        (None, 3, 3, 128)         0
#
#  flatten_28 (Flatten)        (None, 1152)              0
#
#  dense_62 (Dense)            (None, 128)               147584
#
#  dropout_45 (Dropout)        (None, 128)               0
#
#  dense_63 (Dense)            (None, 64)                8256
#
#  dense_64 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 683,535
# Trainable params: 683,535
# Non-trainable params: 0
# _________________________________________________________________
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2395 - accuracy: 0.9317
#
# Test accuracy: 93.17%

# %% [markdown]
# ## Model Analysis

# %% [markdown]
# ### Val loss & Val Acc

# %%
# Evaluate model on validation set
val_loss, val_accuracy = model.evaluate(X_validation, y_validation, verbose=0)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Validation Loss: 0.26993057131767273
# Validation Accuracy: 0.9223333597183228

# %% [markdown]
# ### Confusion Matrix

# %%
# Get the class names
label_names = encoder.classes_

# Calculate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Purples', cbar=False,
           xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion matrix')
tick_marks = np.arange(num_classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Classification Report
print('Classification Report:\n', classification_report(np.argmax(y_test, axis=1), y_pred, target_names=label_names))
# Out:
# 94/94 [==============================] - 1s 5ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#         Bean       0.95      0.96      0.96       200
# Bitter_Gourd       0.91      0.95      0.93       200
# Bottle_Gourd       0.98      0.96      0.97       200
#      Brinjal       0.89      0.93      0.91       200
#     Broccoli       0.89      0.97      0.93       200
#      Cabbage       0.97      0.87      0.92       200
#     Capsicum       0.95      0.95      0.95       200
#       Carrot       0.96      0.88      0.92       200
#  Cauliflower       0.96      0.93      0.94       200
#     Cucumber       0.89      0.98      0.93       200
#       Papaya       0.95      0.94      0.95       200
#       Potato       0.91      0.88      0.89       200
#      Pumpkin       0.91      0.94      0.92       200
#       Radish       0.96      0.92      0.94       200
#       Tomato       0.92      0.92      0.92       200
#
#     accuracy                           0.93      3000
#    macro avg       0.93      0.93      0.93      3000
# weighted avg       0.93      0.93      0.93      3000

# %% [markdown]
# ## Load Model

# %%
from keras.models import load_model

# Load the saved model
model = load_model('best_model_131.h5')

# Compile the model (if needed)
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])

# Evaluate the model on test data (if available)
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print(f'Test accuracy:', f'{test_acc*100:.2f}%')
# Out:
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2395 - accuracy: 0.9317
# Test Loss: 0.23953641951084137
# Test accuracy: 93.17%
